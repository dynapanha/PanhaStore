-- %% [markdown]
-- # [DynaPanha]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DynaPanha]    Script Date: 1/29/2026 12:17:54 AM ******/
CREATE DATABASE [DynaPanha]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'POS', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER1\MSSQL\DATA\POS.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'POS_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER1\MSSQL\DATA\POS_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [DynaPanha] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DynaPanha].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DynaPanha] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DynaPanha] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DynaPanha] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DynaPanha] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DynaPanha] SET ARITHABORT OFF 
GO
ALTER DATABASE [DynaPanha] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [DynaPanha] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DynaPanha] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DynaPanha] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DynaPanha] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DynaPanha] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DynaPanha] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DynaPanha] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DynaPanha] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DynaPanha] SET  DISABLE_BROKER 
GO
ALTER DATABASE [DynaPanha] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DynaPanha] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DynaPanha] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DynaPanha] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DynaPanha] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DynaPanha] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DynaPanha] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DynaPanha] SET RECOVERY FULL 
GO
ALTER DATABASE [DynaPanha] SET  MULTI_USER 
GO
ALTER DATABASE [DynaPanha] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DynaPanha] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DynaPanha] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DynaPanha] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DynaPanha] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DynaPanha] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'DynaPanha', N'ON'
GO
ALTER DATABASE [DynaPanha] SET QUERY_STORE = ON
GO
ALTER DATABASE [DynaPanha] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[tblCategory]

-- %%
USE [DynaPanha]
GO

-- %%
/****** Object:  Table [dbo].[tblCategory]    Script Date: 1/29/2026 12:17:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblCategory](
	[cate_id] [int] IDENTITY(1,1) NOT NULL,
	[cate_name] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[cate_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblDiscount]

-- %%
/****** Object:  Table [dbo].[tblDiscount]    Script Date: 1/29/2026 12:17:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblDiscount](
	[dis_id] [int] IDENTITY(1,1) NOT NULL,
	[dis_percent] [float] NULL,
 CONSTRAINT [PK_tblDiscount] PRIMARY KEY CLUSTERED 
(
	[dis_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblExchangeRate]

-- %%
/****** Object:  Table [dbo].[tblExchangeRate]    Script Date: 1/29/2026 12:17:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblExchangeRate](
	[exc_id] [int] IDENTITY(1,1) NOT NULL,
	[exc_price] [int] NULL,
 CONSTRAINT [PK_tblExchangeRate] PRIMARY KEY CLUSTERED 
(
	[exc_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblOrder]

-- %%
/****** Object:  Table [dbo].[tblOrder]    Script Date: 1/29/2026 12:17:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblOrder](
	[ord_id] [int] IDENTITY(1,1) NOT NULL,
	[ord_date] [date] NULL,
	[ord_time] [time](7) NULL,
	[amount] [float] NULL,
	[seller] [varchar](255) NULL,
	[exc_id] [int] NULL,
	[dis_id] [int] NULL,
 CONSTRAINT [PK_tblOrder] PRIMARY KEY CLUSTERED 
(
	[ord_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblOrderDetail]

-- %%
/****** Object:  Table [dbo].[tblOrderDetail]    Script Date: 1/29/2026 12:17:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblOrderDetail](
	[ord_id] [int] NOT NULL,
	[prod_id] [int] NOT NULL,
	[qty] [int] NULL,
	[unit_price_in] [float] NULL,
	[unit_price_out] [float] NULL,
PRIMARY KEY CLUSTERED 
(
	[ord_id] ASC,
	[prod_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[tblProduct]

-- %%
/****** Object:  Table [dbo].[tblProduct]    Script Date: 1/29/2026 12:17:54 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[tblProduct](
	[prod_id] [int] IDENTITY(1,1) NOT NULL,
	[prod_barcode] [bigint] NULL,
	[prod_name] [nvarchar](155) NULL,
	[prod_qty] [int] NULL,
	[prod_unit_price_in] [float] NULL,
	[prod_unit_price_out] [float] NULL,
	[cate_id] [int] NULL,
 CONSTRAINT [PK_tblProduct] PRIMARY KEY CLUSTERED 
(
	[prod_id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__tblOrder__dis_id__5EBF139D]

-- %%
ALTER TABLE [dbo].[tblOrder]  WITH CHECK ADD FOREIGN KEY([dis_id])
REFERENCES [dbo].[tblDiscount] ([dis_id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__tblOrder__exc_id__5BE2A6F2]

-- %%
ALTER TABLE [dbo].[tblOrder]  WITH CHECK ADD FOREIGN KEY([exc_id])
REFERENCES [dbo].[tblExchangeRate] ([exc_id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__tblOrderD__ord_i__6C190EBB]

-- %%
ALTER TABLE [dbo].[tblOrderDetail]  WITH CHECK ADD FOREIGN KEY([ord_id])
REFERENCES [dbo].[tblOrder] ([ord_id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__tblOrderD__prod___6FE99F9F]

-- %%
ALTER TABLE [dbo].[tblOrderDetail]  WITH CHECK ADD FOREIGN KEY([prod_id])
REFERENCES [dbo].[tblProduct] ([prod_id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__tblProduc__cate___6E01572D]

-- %%
ALTER TABLE [dbo].[tblProduct]  WITH CHECK ADD FOREIGN KEY([cate_id])
REFERENCES [dbo].[tblCategory] ([cate_id])
ON UPDATE CASCADE
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [DynaPanha]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DynaPanha] SET  READ_WRITE 
GO
